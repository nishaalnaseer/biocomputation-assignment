# %%
import pandas as pd

# %%
dataset = pd.read_csv("AB_NYC_2019.csv")

# %%
n = dataset.groupby("neighbourhood")
for nn in n:
    print(nn)
# Out:
# ('Allerton',              id                                               name    host_id  \
# 510      182177              A PRIVATE FLAT / APARTMENT- $SPECIAL$     873273
# 1167     498120                              Hi Traveler.. welcome    2459648
# 1578     715270  2 Beds/Queen & Full Beautiful Room 40 minsT.Sq...    3684360
# 1666     755528                 PRIVATE BATH/TONS OF SUNLIGHT/SAFE    3684360
# 1706     773041                   Nice beautiful room In the Bronx    3684360
# 4795    3400359                                   Awesome Deal NYC   16286162
# 4826    3429765                                 Sunny Private Room   16286162
# 6023    4407790                                       Retreat Room   16286162
# 6097    4462008                                         Twin  room   16286162
# 7018    5046189  Modern/Spacious 4BR +Tent Perfect for LARGE gr...   23732730
# 10781   8294259  Room in Private House(Queen Bed) by Montefiore...   11305944
# ...

# %%
n.plot()
# Out:
# C:\Users\nishaalnaseer\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\plotting\_matplotlib\core.py:580: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   fig = self.plt.figure(figsize=self.figsize)
# neighbourhood
# Allerton           Axes(0.125,0.11;0.775x0.77)
# Arden Heights      Axes(0.125,0.11;0.775x0.77)
# Arrochar           Axes(0.125,0.11;0.775x0.77)
# Arverne            Axes(0.125,0.11;0.775x0.77)
# Astoria            Axes(0.125,0.11;0.775x0.77)
#                               ...
# Windsor Terrace    Axes(0.125,0.11;0.775x0.77)
# Woodhaven          Axes(0.125,0.11;0.775x0.77)
# Woodlawn           Axes(0.125,0.11;0.775x0.77)
# Woodrow            Axes(0.125,0.11;0.775x0.77)
# ...
